# %% [markdown]
# <a href="https://colab.research.google.com/github/MOUSMIFAROUQ/Design-Patterns-In-Python/blob/master/whisper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install git+https://github.com/openai/whisper.git
 # !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-g8ou9i63
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-g8ou9i63
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.9 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802825 sha256=67861460d52d9e7e67b4078e7f1976f6e50dca3ac99c07b9e2a5d51ba6db9908
#   Stored in directory: /tmp/pip-ephem-wheel-cache-svg514rj/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# ...

# %%
 # !whisper "Teams.mp3" --model medium
# Out:
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: French
# [00:00.000 --> 00:15.360]  Alors, tiens juste pour info, Abdelharim démissionne aujourd'hui, il a trouvé un job chez Capgemini,
# [00:15.360 --> 00:17.360]  il commence ta vie prochainement.
# [00:17.360 --> 00:19.360]  C'est bien, c'est bien, tant mieux pour lui.
# [00:19.360 --> 00:21.360]  Je suis content pour lui, je suis content pour lui.
# [00:21.360 --> 00:23.360]  Il commence quand du coup, il quitte quand ?
# [00:23.360 --> 00:25.360]  Fin de semaine.
# [00:25.360 --> 00:27.360]  Fin de semaine.
# [00:27.360 --> 00:29.360]  Ok ok, ça marche.
# [00:30.160 --> 00:36.240]  Et je ne sais plus si on l'avait partagé, mais c'est quelque chose que je lui ai dit hier et que j'ai beaucoup apprécié de sa part.
# [00:38.240 --> 00:44.640]  Bon, il y a eu des moments un peu compliqués où il n'y a pas toujours eu la vérité qui a été mise sur la table.
# ...

# %%
# !pip install --q git+https://github.com/m-bain/whisperx.git
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 19.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.7/208.7 kB 22.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 45.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 101.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 101.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 7.5 MB/s eta 0:00:00
# ...

# %%
import whisperx
import gc

# %%
# device = "cuda"
# batch_size = 16 # reduce if low on GPU mem
# compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)

# %%
device = "cuda"
batch_size = 4 # reduce if low on GPU mem
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)

# %%
# 1. Transcribe with original whisper (batched)
model = whisperx.load_model("large-v2", device, compute_type=compute_type)
# Out:
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.1. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.1.0+cu121. Bad things might happen unless you revert torch to 1.x.

# %%
audio_file = "Teams.mp3"

# %%
audio = whisperx.load_audio(audio_file)
result = model.transcribe(audio, batch_size=batch_size)
print(result["segments"]) # before alignment
# Out:
# Detected language: fr (0.97) in first 30s of audio...
# ...

# %%
result = model.transcribe(audio, batch_size=batch_size)
print(result["segments"]) # before alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model

# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)
# Out:
# Detected language: fr (0.97) in first 30s of audio...
# ...

# %%
result
# Out:
# {'segments': [{'start': 4.432,
#    'end': 11.897,
#    'text': " Abdelharim démissionne aujourd'hui.",
#    'words': [{'word': 'Abdelharim',
#      'start': 4.432,
#      'end': 8.114,
#      'score': 0.524},
#     {'word': 'démissionne', 'start': 8.134, 'end': 8.494, 'score': 0.731},
#     {'word': "aujourd'hui.", 'start': 8.535, 'end': 11.897, 'score': 0.822}]},
#   {'start': 11.977,
#    'end': 15.379,
#    'text': 'Il a trouvé un job chez Capgemini.',
#    'words': [{'word': 'Il', 'start': 11.977, 'end': 12.037, 'score': 0.72},
#     {'word': 'a', 'start': 12.097, 'end': 12.137, 'score': 0.907},
#     {'word': 'trouvé', 'start': 12.177, 'end': 12.377, 'score': 0.926},
#     {'word': 'un', 'start': 12.437, 'end': 12.537, 'score': 0.686},
#     {'word': 'job', 'start': 12.557, 'end': 14.158, 'score': 0.84},
#     {'word': 'chez', 'start': 14.198, 'end': 14.358, 'score': 0.646},
#     {'word': 'Capgemini.', 'start': 14.378, 'end': 15.379, 'score': 0.784}]},
#   {'start': 15.459,
# ...

# %%
diarize_model = whisperx.DiarizationPipeline(use_auth_token="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", device=device)
# Out:
# pytorch_model.bin:   0%|          | 0.00/5.91M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/399 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]

# %%
diarize_segments = diarize_model(audio, min_speakers=2, max_speakers=2)

# %%
diarize_segments
# Out:
#                                segment label     speaker       start  \
# 0    [ 00:00:00.008 -->  00:00:00.127]     A  SPEAKER_01    0.008489
# 1    [ 00:00:00.127 -->  00:00:00.178]     B  SPEAKER_00    0.127334
# 2    [ 00:00:03.064 -->  00:00:09.380]     C  SPEAKER_01    3.064516
# 3    [ 00:00:10.110 -->  00:00:10.636]     D  SPEAKER_01   10.110357
# 4    [ 00:00:10.670 -->  00:00:16.392]     E  SPEAKER_01   10.670628
# ..                                 ...   ...         ...         ...
# 168  [ 00:09:31.791 -->  00:09:35.186]    FM  SPEAKER_00  571.791171
# 169  [ 00:09:36.578 -->  00:09:39.685]    FN  SPEAKER_00  576.578947
# 170  [ 00:09:40.466 -->  00:09:43.471]    FO  SPEAKER_01  580.466893
# 171  [ 00:09:43.607 -->  00:09:44.049]    FP  SPEAKER_00  583.607810
# 172  [ 00:09:45.458 -->  00:09:45.865]    FQ  SPEAKER_01  585.458404
#
#             end
# 0      0.127334
# 1      0.178268
# 2      9.380306
# 3     10.636672
# 4     16.392190
# ..          ...
# ...

# %%
diarize_segments.speaker.unique()
# Out:
# array(['SPEAKER_01', 'SPEAKER_00'], dtype=object)

# %%
result = whisperx.assign_word_speakers(diarize_segments, result)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs
# Out:
#                                segment label     speaker       start  \
# 0    [ 00:00:00.008 -->  00:00:00.127]     A  SPEAKER_01    0.008489
# 1    [ 00:00:00.127 -->  00:00:00.178]     B  SPEAKER_00    0.127334
# 2    [ 00:00:03.064 -->  00:00:09.380]     C  SPEAKER_01    3.064516
# 3    [ 00:00:10.110 -->  00:00:10.636]     D  SPEAKER_01   10.110357
# 4    [ 00:00:10.670 -->  00:00:16.392]     E  SPEAKER_01   10.670628
# ..                                 ...   ...         ...         ...
# 168  [ 00:09:31.791 -->  00:09:35.186]    FM  SPEAKER_00  571.791171
# 169  [ 00:09:36.578 -->  00:09:39.685]    FN  SPEAKER_00  576.578947
# 170  [ 00:09:40.466 -->  00:09:43.471]    FO  SPEAKER_01  580.466893
# 171  [ 00:09:43.607 -->  00:09:44.049]    FP  SPEAKER_00  583.607810
# 172  [ 00:09:45.458 -->  00:09:45.865]    FQ  SPEAKER_01  585.458404
#
#             end  intersection       union
# 0      0.127334   -585.391666  585.670511
# 1      0.178268   -585.340732  585.551666
# ...

# %% [markdown]
# ### Word Level Transcription

# %%
result
# Out:
# {'segments': [{'text': " Abdelharim démissionne aujourd'hui. Il a trouvé un job chez Capgemini. Il commence la vie prochaine. Il commence la vie prochaine. C'est bien, c'est bien, tant mieux pour lui. Je suis content pour lui, je suis content pour lui. Il commence quand du coup ? Il quitte quand ? C'est la fin de semaine. La fin de semaine. Ok, ok, ça marche.",
#    'start': 0.009,
#    'end': 29.428},
#   {'text': " Et je ne sais plus si on l'avait partagé, mais c'est quelque chose que je lui ai dit hier et que j'ai beaucoup apprécié de sa part. Il y a eu des moments un peu compliqués où il n'y a pas toujours eu la vérité qui a été mise sur la table. Et il a fini par, à un moment donné, se confier et puis il a dit les choses. Voilà. Il faut un certain courage pour le faire. Et je ne sais pas si vous l'aviez vu, je ne sais pas si vous êtes dans son cercle",
#    'start': 30.213,
#    'end': 58.968},
# ...

# %%
# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code=result["language"],
                                              device=device)

result = whisperx.align(result["segments"], model_a,
                        metadata,
                        audio,
                        device,
                        return_char_alignments=False)

print(result["segments"]) # after alignment
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_voxpopuli_base_10k_asr_fr.pt" to /root/.cache/torch/hub/checkpoints/wav2vec2_voxpopuli_base_10k_asr_fr.pt
# 100%|██████████| 360M/360M [00:25<00:00, 14.9MB/s]
# ...
